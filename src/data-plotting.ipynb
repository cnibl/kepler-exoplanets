# %% [markdown]
# # Data plotting
# This notebook visualises the data in the input data file `../inputdata/keplerdata.csv`, constructing plots and figures. We use the dataset consisting of observations with the Kepler telescope, that looks for exoplanets.

# %%
# Necessary imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# Show plots in notebook cells
# %matplotlib inline 
sns.set(style="darkgrid")

# %%
# Read in the data in a DataFrame
kepler_data = pd.read_csv("../inputdata/keplerdata.csv")

# %%
kepler_data.head()
# Out:
#    rowid     kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0      1  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1      2  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2      3  10811496  K00753.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 3      4  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4      5  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co     ...      \
# 0      1.000              0              0              0     ...
# 1      0.969              0              0              0     ...
# 2      0.000              0              1              0     ...
# 3      0.000              0              1              0     ...
# 4      1.000              0              0              0     ...
#
#    koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# ...

# %%
kepler_data.describe()
# Out:
#              rowid         kepid    koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# count  9564.000000  9.564000e+03  8054.000000    9564.000000    9564.000000
# mean   4782.500000  7.690628e+06     0.480829       0.188206       0.231598
# std    2761.033321  2.653459e+06     0.476928       0.390897       0.421875
# min       1.000000  7.574500e+05     0.000000       0.000000       0.000000
# 25%    2391.750000  5.556034e+06     0.000000       0.000000       0.000000
# 50%    4782.500000  7.906892e+06     0.334000       0.000000       0.000000
# 75%    7173.250000  9.873066e+06     0.998000       0.000000       0.000000
# max    9564.000000  1.293514e+07     1.000000       1.000000       1.000000
#
#        koi_fpflag_co  koi_fpflag_ec     koi_period  koi_period_err1  \
# count    9564.000000    9564.000000    9564.000000      9110.000000
# mean        0.194898       0.120033      75.671358         0.002148
# std         0.396143       0.325018    1334.744046         0.008236
# ...

# %%
kepler_data.count()
# Out:
# rowid                9564
# kepid                9564
# kepoi_name           9564
# kepler_name          2294
# koi_disposition      9564
# koi_pdisposition     9564
# koi_score            8054
# koi_fpflag_nt        9564
# koi_fpflag_ss        9564
# koi_fpflag_co        9564
# koi_fpflag_ec        9564
# koi_period           9564
# koi_period_err1      9110
# koi_period_err2      9110
# koi_time0bk          9564
# koi_time0bk_err1     9110
# koi_time0bk_err2     9110
# koi_impact           9201
# koi_impact_err1      9110
# koi_impact_err2      9110
# koi_duration         9564
# koi_duration_err1    9110
# koi_duration_err2    9110
# koi_depth            9201
# koi_depth_err1       9110
# koi_depth_err2       9110
# koi_prad             9201
# koi_prad_err1        9201
# koi_prad_err2        9201
# koi_teq              9201
# koi_teq_err1            0
# koi_teq_err2            0
# koi_insol            9243
# koi_insol_err1       9243
# koi_insol_err2       9243
# ...

# %% [markdown]
# # Position on the sky
# The plot below shows the position on the night sky where the objects are, in terms of right ascension (`ra`) and declination (`dec`). The observations come from a fairly small portion compared to the whole sky (about 15 times 20 degrees).

# %%
jp = sns.jointplot(x="ra", y="dec", data=kepler_data, kind="hex", space=0)

# %% [markdown]
# # Classification
# The two plots below show the classification of the observed objects, `koi_pdisposition` is the classification from the Kepler data alone whereas `koi_disposition` also includes information from the Exoplanet Archive (an exoplanet database), with the Kepler classification used for objects which are not deemed `CONFIRMED`.
#
# `CONFIRMED` objects are in the Exoplanet Archive designated as confirmed exoplanetary objects. `CANDIDATE` objects are those observed by Kepler that have passed a number of tests to determine whether it is a suitable candidate, `FALSE POSITIVE` objects have failed at least one of these tests.

# %%
sns.countplot(x="koi_disposition", data=kepler_data)

# %%
sns.countplot(x="koi_pdisposition", data=kepler_data)

# %% [markdown]
# # Identifying correlating variables
# To find which of the many variables that are mostly correlated with the classification of an object (its `koi_pdisposition` and `koi_disposition` values), we look at the correlation matrix between the different variables. We drop unnecessary columns with names and measurement errors.

# %%
kepler_reduced = kepler_data.drop(['rowid', 'kepid', 'kepoi_name', 'kepler_name', 'koi_tce_delivname', 
                     'koi_period_err1', 'koi_period_err2', 
                     'koi_time0bk_err1', 'koi_time0bk_err2', 
                     'koi_impact_err1', 'koi_impact_err2',
                     'koi_depth_err1', 'koi_depth_err2', 
                     'koi_prad_err1', 'koi_prad_err2', 
                     'koi_insol_err1', 'koi_insol_err2',
                     'koi_steff_err1', 'koi_steff_err2', 
                     'koi_slogg_err1', 'koi_slogg_err2', 
                     'koi_srad_err1', 'koi_srad_err2', 
                     'koi_duration_err1', 'koi_duration_err2', 
                     'koi_teq_err1', 'koi_teq_err2'], axis=1)
kepler_reduced = kepler_reduced.replace({"CONFIRMED": 0, "CANDIDATE": 1, "FALSE POSITIVE": 2})
corr_matrix = kepler_reduced.corr()
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(abs(corr_matrix), cmap="binary", square=True)
abs(corr_matrix[["koi_disposition", "koi_pdisposition"]])
# Out:
#                   koi_disposition  koi_pdisposition
# koi_disposition          1.000000          0.894850
# koi_pdisposition         0.894850          1.000000
# koi_score                0.897774          0.973559
# koi_fpflag_nt            0.402578          0.453512
# koi_fpflag_ss            0.449329          0.496235
# koi_fpflag_co            0.421427          0.463418
# koi_fpflag_ec            0.318444          0.347867
# koi_period               0.009439          0.001783
# koi_time0bk              0.058399          0.034463
# koi_impact               0.071992          0.073116
# koi_duration             0.152575          0.156686
# koi_depth                0.240949          0.261532
# koi_prad                 0.027518          0.029330
# koi_teq                  0.239785          0.253689
# koi_insol                0.031962          0.029737
# koi_model_snr            0.206208          0.233683
# koi_tce_plnt_num         0.208069          0.185785
# ...

# %% [markdown]
# ## Most correlating variables
# The variables that are most correlated are the ones in the below heatmap. They should be most relevant for determining how an object should be classified.

# %%
kepler_mostcorr = kepler_reduced.drop(["koi_period", "koi_time0bk", "koi_impact", "koi_duration",
                                       "koi_prad", "koi_insol", "koi_steff", "koi_srad",
                                       "ra", "dec", "koi_kepmag", "koi_slogg"], axis=1)
print(kepler_mostcorr.columns)
sns.heatmap(abs(kepler_mostcorr.corr()), cmap="binary")
# Out:
# Index(['koi_disposition', 'koi_pdisposition', 'koi_score', 'koi_fpflag_nt',
#        'koi_fpflag_ss', 'koi_fpflag_co', 'koi_fpflag_ec', 'koi_depth',
#        'koi_teq', 'koi_model_snr', 'koi_tce_plnt_num'],
#       dtype='object')

# %% [markdown]
# # Pairwise scatter plots
# Below are scatter plots showing the separations between the classes for the most correlating variables of `float` type (the `fpflag` variables are discrete with value of 0 or 1). We see that the separation between the classes is not too great, which will mean that even if these are variables that correlate strongly with the classification, we run a risk of not getting a very good classification accuracy in the end.

# %%
plot_cols = ["koi_depth","koi_teq","koi_model_snr","koi_tce_plnt_num"]
kepler_mostcorr[plot_cols].dtypes
no_nan = kepler_mostcorr.copy()
no_nan.fillna(kepler_mostcorr.mean(), inplace=True)
sns.pairplot(x_vars=plot_cols, y_vars=plot_cols, data=no_nan, hue="koi_disposition", hue_order=[2,1,0], diag_kind="kde")

# %% [markdown]
# # Conclusion of analysis of data variables
# With the above in mind, it is clear that a classification analysis aiming at predicting whether an object is a `CANDIDATE` or a `FALSE POSITIVE` should primarily use the columns with the most correlating variables. Not surprisingly, the `fp_flag` variables, that designate whether an object has passed the false positive tests are important.

# %% [markdown]
# # Analysis of missing values
# It is important to use as much of the data as possible in the analysis, but missing values `NaN` have to be treated since the models need numerical input. Below we look at whether there are missing values in the remaining predictor columns and the prediction target.

# %%
# We will not predict `koi_disposition`, but will only only at the prediction from Kepler – `koi_pdisposition`
y = kepler_mostcorr["koi_pdisposition"] 
y.name
# Out:
# 'koi_pdisposition'

# %%
# X will contain our predictor columns
X = kepler_mostcorr.drop(["koi_pdisposition", "koi_disposition"], axis=1)
X.columns
# Out:
# Index(['koi_score', 'koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
#        'koi_fpflag_ec', 'koi_depth', 'koi_teq', 'koi_model_snr',
#        'koi_tce_plnt_num'],
#       dtype='object')

# %% [markdown]
# There are no missing values for the prediction target

# %%
print(y.size)
print(y.dropna().size)
# Out:
# 9564
# 9564

# %% [markdown]
# There are some missing values from some of the data columns, below we show the percent of values that are non-numeric (i.e. `NaN` or something similar). In particular the `koi_score` column has a significant number of missing values.

# %%
print(1.-X.count()/y.size)
# Out:
# koi_score           0.157884
# koi_fpflag_nt       0.000000
# koi_fpflag_ss       0.000000
# koi_fpflag_co       0.000000
# koi_fpflag_ec       0.000000
# koi_depth           0.037955
# koi_teq             0.037955
# koi_model_snr       0.037955
# koi_tce_plnt_num    0.036177
# dtype: float64

# %%
print(X.koi_score.loc[X.koi_score==0].size)
X.koi_score.plot.hist(bins=100)
# Out:
# 3482

# %%
X.koi_depth.plot.hist(bins=100)

# %%
X.koi_teq.plot.hist(bins=100)

# %%
X.koi_model_snr.plot.hist(bins=100)

# %%
X.koi_tce_plnt_num.plot.hist(bins=100)

# %%
X.describe()
# Out:
#          koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# count  8054.000000    9564.000000    9564.000000    9564.000000
# mean      0.480829       0.188206       0.231598       0.194898
# std       0.476928       0.390897       0.421875       0.396143
# min       0.000000       0.000000       0.000000       0.000000
# 25%       0.000000       0.000000       0.000000       0.000000
# 50%       0.334000       0.000000       0.000000       0.000000
# 75%       0.998000       0.000000       0.000000       0.000000
# max       1.000000       1.000000       1.000000       1.000000
#
#        koi_fpflag_ec     koi_depth       koi_teq  koi_model_snr  \
# count    9564.000000  9.201000e+03   9201.000000    9201.000000
# mean        0.120033  2.379134e+04   1085.385828     259.895001
# std         0.325018  8.224268e+04    856.351161     795.806615
# min         0.000000  0.000000e+00     25.000000       0.000000
# 25%         0.000000  1.599000e+02    539.000000      12.000000
# ...
